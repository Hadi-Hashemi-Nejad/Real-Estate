# %%
import requests
import json
import pandas as pd
pd.set_option('display.max_columns', None)
import os

# %%
def DLD_get_access_token():
    access_token_command = "curl -X POST \"https://api.dubaipulse.gov.ae/oauth/client_credential/accesstoken?grant_type=client_credentials\" -d \"client_id=pKYG2fv0ie4NfmhW7satv4AShtx5PPkx&client_secret=AA8l7Qc8mq3TsB39\""
    print("Dubai Pulse access token recieved")
    return "Bearer " + json.loads(os.popen(access_token_command).read())["access_token"]

def get_DLD_transactions(offset, DLD_access_token):
    headers = {"Authorization": DLD_access_token}
    url = "https://api.dubaipulse.gov.ae/open/dld/dld_transactions-open-api?order_by=instance_date&filter=area_id=390 AND procedure_id=11 AND property_sub_type_id=60&offset="+str(offset)
    response = requests.get(url, headers=headers).json()
    if next(iter(response)) == 'fault':
        DLD_access_token = DLD_get_access_token()
        get_DLD_transactions(offset)
    else:
        return pd.DataFrame(response["results"])

# %%
def loop_DLD_transactions():
    DLD_access_token = DLD_get_access_token()
    offset = 12000 #This will need to be read and updated to s3 everytime
    df = pd.DataFrame(columns=['transaction_id']) #This will need to be changed to read old transactions from s3

    DLD_API_call = get_DLD_transactions(offset, DLD_access_token)
    while sum(DLD_API_call.transaction_id.isin(df.transaction_id).astype(int)) < len(DLD_API_call):
        print("%d rows were appended to DLD transactions"%len(DLD_API_call))
        df = pd.concat([df, DLD_API_call[~DLD_API_call.transaction_id.isin(df.transaction_id)]], ignore_index=True)
        offset = offset + 1000
        DLD_API_call = get_DLD_transactions(offset, DLD_access_token)
        if DLD_API_call.empty:
            break
    
    return df

# %%
df = loop_DLD_transactions()

# %%
DLD_access_token = DLD_get_access_token()
# Out:
# Dubai Pulse access token recieved

# %%
headers = {"Authorization": DLD_access_token}
url = "https://api.dubaipulse.gov.ae/open/dld/dld_transactions-open-api?order_by=instance_date&filter=area_id=390 AND procedure_id=11 AND property_sub_type_id=60&offset=17000"
response = requests.get(url, headers=headers).json()
# df2 = pd.DataFrame(response["results"])

# %%
response
# Out:
# {'name': 'Quota Exceeded Error',
#  'errorString': 'The valid quota has been exceeded'}

# %%
bayut_url = "https://www.bayut.com/property-market-analysis/sale/dubai/downtown-dubai/boulevard-point/?time_since_creation=36m&beds=2"
bayut_url_response = requests.get(bayut_url)

# %%
print(bayut_url_response.content)
# Out:
# b'<!DOCTYPE html><html lang="en" dir="ltr" itemscope="" searchhistory="original" searchhistorymobile="original" itemType="http://schema.org/WebPage"><head><meta charSet="UTF-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0"/><link rel="dns-prefetch" href="http://LL8IZ711CS-dsn.algolia.net"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="dns-prefetch" href="https://www.google-analytics.com"/><link rel="dns-prefetch" href="https://images.bayut.com"/><link rel="apple-touch-icon" sizes="180x180" href="/assets/apple-touch-icon.7919a66ff6f58dbfb1d2e33cb19b5a80.png"/><link rel="icon" type="image/png" sizes="16x16" href="/assets/favicon-16x16.0e9b01e26e8e124b4b030829ed6e5bfb.png"/><link rel="icon" type="image/png" sizes="32x32" href="/assets/favicon-32x32.20ce04f8a637e94fd0dc5ca4eeab1dce.png"/><link rel="manifest" href="/assets/cfd539f6f9fa15a35156f806828fe844.json"/><link rel="mask-icon" href="/assets/safari-pinned-tab.f33e518f84388363bf4cb34c90eec2a6.svg" color="#28b16d"/><meta name="theme-color" content="#ffffff"/><title>Sale Transactions &amp; Prices for 2 Bedroom Properties in Boulevard Point | Bayut.com</title><meta name="description" content="Check out the latest Sale transactions for 2 Bedroom Properties in Boulevard Point on Bayut.com, sourced directly from DLD. Get insights on average Sale prices, historical transactions &amp; price trends for 2 Bedroom Properties in Boulevard Point."/><link rel="canonical" href="https://www.bayut.com/property-market-analysis/sale/dubai/downtown-dubai/boulevard-point/"/><meta property="og:url" content="https://www.bayut.com/property-market-analysis/sale/dubai/downtown-dubai/boulevard-point/"/><meta itemProp="url" content="https://www.bayut.com/property-market-analysis/sale/dubai/downtown-dubai/boulevard-point/"/><link rel="alternate" href="https://www.bayut.com/property-market-analysis/sale/dubai/downtown-dubai/boulevard-point/" hrefLang="en"/><link rel="alternate" href="https://www.bayut.com/ar/property-market-analysis/sale/dubai/downtown-dubai/boulevard-point/" hrefLang="ar"/><link rel="alternate" href="https://www.bayut.com/zh/property-market-analysis/sale/dubai/downtown-dubai/boulevard-point/" hrefLang="zh"/><link rel="alternate" href="https://www.bayut.com/ru/property-market-analysis/sale/dubai/downtown-dubai/boulevard-point/" hrefLang="ru"/><meta name="robots" content="noindex, follow"/><script>window[\'dataLayer\'] = window[\'dataLayer\'] || [];window[\'dataLayer\'].push({"experiments":{"SearchHistory":"original","SearchHistoryMobile":"original"},"device_type":"d","app_agent_version":"1.0","app_agent":"web","app_environment":"production","language":"en","area_unit":"Sq. Ft.","currency_unit":"AED","layout_preference":"list","url":"https:\\u002F\\u002Fwww.bayut.com\\u002Fproperty-market-analysis\\u002Fsale\\u002Fdubai\\u002Fdowntown-dubai\\u002Fboulevard-point\\u002F?time_since_creation=36m&beds=2","query_params":"?time_since_creation=36m&beds=2","route":{"routeName":"propertyMarketAnalysis","routeParams":{"purpose":"sale","primaryLocation":"dubai\\u002Fdowntown-dubai\\u002Fboulevard-point","time_since_creation":"36m","beds":"2"},"url":"\\u002Fproperty-market-analysis\\u002Fsale\\u002Fdubai\\u002Fdowntown-dubai\\u002Fboulevard-point\\u002F?time_since_creation=36m&beds=2","originalURL":"\\u002Fproperty-market-analysis\\u002Fsale\\u002Fdubai\\u002Fdowntown-dubai\\u002Fboulevard-point\\u002F?time_since_creation=36m&beds=2","referrer":null,"originalReferrer":null,"landingURL":"\\u002Fproperty-market-analysis\\u002Fsale\\u002Fdubai\\u002Fdowntown-dubai\\u002Fboulevard-point\\u002F?time_since_creation=36m&beds=2"},"referrer":null,"website_referrer":null,"starting_page_url":"https:\\u002F\\u002Fwww.bayut.com\\u002Fproperty-market-analysis\\u002Fsale\\u002Fdubai\\u002Fdowntown-dubai\\u002Fboulevard-point\\u002F?time_since_creation=36m&beds=2","anonymous_session_id":"b03a3d8c-95b1-4761-915a-ac7e4672f8f0","user_profile":{"user ...

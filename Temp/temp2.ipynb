# %%
import requests
from io import BytesIO
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
url = 'https://www.dubaipulse.gov.ae/dataset/3b25a6f5-9077-49d7-8a1e-bc6d5dea88fd/resource/a37511b0-ea36-485d-bccd-2d6cb24507e7/download/transactions.csv'
r1 = requests.get(url)
tr = pd.read_csv(BytesIO(r1.content))
tr = tr[tr["property_type_en"]=="Unit"].sort_values("instance_date", ascending=False)

# %%
url2 = 'https://www.dubaipulse.gov.ae/dataset/85462a5b-08dc-4325-9242-676a0de4afc4/resource/7d4deadf-c9bc-47a4-85de-998d0ce38bf3/download/units.csv'
r2 = requests.get(url2)
un = pd.read_csv(BytesIO(r2.content))
# Out:
# /tmp/ipykernel_26130/2322835276.py:3: DtypeWarning: Columns (3,4,7,10,12,13,16,18,19,22,23,25,26,29,36,38,39,41,42,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   un = pd.read_csv(BytesIO(r2.content))

# %%
tr.columns
# Out:
# Index(['transaction_id', 'procedure_id', 'trans_group_id', 'trans_group_ar',
#        'trans_group_en', 'procedure_name_ar', 'procedure_name_en',
#        'instance_date', 'property_type_id', 'property_type_ar',
#        'property_type_en', 'property_sub_type_id', 'property_sub_type_ar',
#        'property_sub_type_en', 'property_usage_ar', 'property_usage_en',
#        'reg_type_id', 'reg_type_ar', 'reg_type_en', 'area_id', 'area_name_ar',
#        'area_name_en', 'building_name_ar', 'building_name_en',
#        'project_number', 'project_name_ar', 'project_name_en',
#        'master_project_en', 'master_project_ar', 'nearest_landmark_ar',
#        'nearest_landmark_en', 'nearest_metro_ar', 'nearest_metro_en',
#        'nearest_mall_ar', 'nearest_mall_en', 'rooms_ar', 'rooms_en',
#        'has_parking', 'procedure_area', 'actual_worth', 'meter_sale_price',
#        'rent_value', 'meter_rent_price', 'no_of_parties_role_1',
#        'no_of_parties_role_2', 'no_of_parties_role_3'],
# ...

# %%
un.columns
# Out:
# Index(['property_id', 'area_id', 'zone_id', 'area_name_ar', 'area_name_en',
#        'land_number', 'land_sub_number', 'building_number', 'unit_number',
#        'unit_balcony_area', 'unit_parking_number', 'parking_allocation_type',
#        'parking_allocation_type_ar', 'parking_allocation_type_en',
#        'common_area', 'actual_common_area', 'floor', 'rooms', 'rooms_ar',
#        'rooms_en', 'actual_area', 'property_type_id', 'property_type_ar',
#        'property_type_en', 'property_sub_type_id', 'property_sub_type_ar',
#        'property_sub_type_en', 'parent_property_id', 'grandparent_property_id',
#        'creation_date', 'munc_zip_code', 'munc_number', 'parcel_id',
#        'is_free_hold', 'is_lease_hold', 'is_registered',
#        'pre_registration_number', 'master_project_id', 'master_project_en',
#        'master_project_ar', 'project_id', 'project_name_ar', 'project_name_en',
#        'land_type_id', 'land_type_ar', 'land_type_en'],
#       dtype='object')

# %%
tr[tr["reg_type_id"]!=0].head()
# Out:
#          transaction_id  procedure_id  trans_group_id trans_group_ar  \
# 111193  1-11-2021-23524            11               1        مبايعات
# 814279   1-41-2020-7872            41               1        مبايعات
# 513378  1-11-2020-13171            11               1        مبايعات
# 133840  1-11-2020-13245            11               1        مبايعات
# 370800  1-11-2020-13239            11               1        مبايعات
#
#        trans_group_en procedure_name_ar procedure_name_en instance_date  \
# 111193          Sales               بيع              Sell    31-12-2021
# 814279          Sales         بيع مبدئى      Delayed Sell    31-12-2020
# 513378          Sales               بيع              Sell    31-12-2020
# 133840          Sales               بيع              Sell    31-12-2020
# 370800          Sales               بيع              Sell    31-12-2020
#
#         property_type_id property_type_ar property_type_en  \
# ...

# %%
un.head()
# Out:
#    property_id  area_id  zone_id    area_name_ar      area_name_en  \
# 0   1300000003    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
# 1   1300000004    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
# 2   1300000005    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
# 3   1300000006    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
# 4   1300000007    351.0      2.0  الثنيه الثالثة  Al Thanyah Third
#
#    land_number  land_sub_number building_number unit_number  \
# 0         31.0              0.0               2         207
# 1         34.0              0.0               1         G01
# 2         34.0              0.0               1         G02
# 3         34.0              0.0               1         G03
# 4         34.0              0.0               1         G04
#
#    unit_balcony_area unit_parking_number  parking_allocation_type  \
# 0              19.97         B-63 , B-64                      NaN
# ...

# %%
temp[temp["land_type_en"]=='Residential']
# Out:
#         property_id  area_id  zone_id      area_name_ar         area_name_en  \
# 2583     1200002648      351        2    الثنيه الثالثة     Al Thanyah Third
# 2584     1200002649      351        2    الثنيه الثالثة     Al Thanyah Third
# 2585     1200002650      351        2    الثنيه الثالثة     Al Thanyah Third
# 2586     1200002651      351        2    الثنيه الثالثة     Al Thanyah Third
# 4960     1200005035      351        2    الثنيه الثالثة     Al Thanyah Third
# ...             ...      ...      ...               ...                  ...
# 192392   2800050206      473        1        وادي الشبك        Wadi Alshabak
# 192397   2800050211      340        2        غدير الطير      Ghadeer Al tair
# 192404   2800050218      406        2  ند الشبا الرابعه  Nad Al Shiba Fourth
# 192409   2800050223      473        1        وادي الشبك        Wadi Alshabak
# 192410   2800050224      473        1        وادي الشبك        Wadi Alshabak
#
# ...

# %%
url3 = 'https://www.dubaipulse.gov.ae/dataset/04168da5-9d10-4fe3-bd29-6dba97751435/resource/6450b4a5-f9c5-4aca-8e64-b38aa8db4c5a/download/buildings.csv'
r3 = requests.get(url3)

# %%
temp = pd.read_csv(BytesIO(r3.content))
# Out:
# /tmp/ipykernel_26130/2463982015.py:1: DtypeWarning: Columns (35,37,38,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp = pd.read_csv(BytesIO(r3.content))
